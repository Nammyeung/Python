# %% [markdown]
# <a href="https://colab.research.google.com/github/Nammyeung/Python/blob/master/%EC%84%A0%ED%98%95_%EB%B0%B0%EC%97%B4_(feat_%EC%8B%9C%EA%B0%84_%EB%B3%B5%EC%9E%A1%EB%8F%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#O(1)

L = [ 'Bob', 'Cat', 'Spam', 'Programmers']

L

L[1]

L[-2]

L.append('New')

L

L = ['Bob', 'Cat', 'Spam', 'Programmers']
L.pop()

L

#O(n)

L = [20, 37, 58, 72, 91]

# index 3 의 위치에 원소 65를 삽입하라.
L.insert(3,65)

L = [20, 37, 58, 72, 91]
L

# index 2 위치한 원소를 삭제하라
del(L[2])

L

import time

sample = list(range(30000000))
len(sample)

ts = time.time()
sample.pop(15000000)
elapsed = time.time() - ts
print("pop 속도 : " , len(sample), elapsed)

sample = list(range(30000000))
len(sample)

ts = time.time()
del(sample[15000000])

elapsed = time.time() - ts
print("del 속도 : " , len(sample), elapsed)

L = ['Bob', 'Cat', 'Spam', 'Programmers']
L.index('Spam')

# 방법1

def solution(L, x):
  L.append(x)
  L.sort()
  answer = L
  return answer

L = [20, 37, 58, 72, 91]

solution(L, 65)

# 방법2

def solution(L, x):
  for num in L:
    if x > num:
      pass
    else:
      a = L.index(num)
      L.insert(a, x)
      break
  return L

L = [20, 37, 58, 72, 91]
solution(L,65)

L = [20, 37, 58, 72, 91]
solution(L,100)

# 방법2 - 1

def solution(L, x):
  for num in L:
    if x > num:
      pass
    else:
      a = L.index(num)
      L.insert(a,x)
      break

  if L[-1]<x:
    L.append(x)
  elif L[0]>x:
    L.insert(0,x)

  return L

L = [20, 37, 58, 72, 91]
solution(L, 100)

L = [20, 37, 58, 72, 91]
solution(L, 65)

#enumerate
L = [20, 37, 58, 72, 91]
for num, l in enumerate(L):
  print(num, l)
  
# enumerate 해서 하나의 원소만 꺼내게 하면 결합된 인덱스 번호까지 튜플로 나오게 된다.
for num in enumerate(L):
  print(num)

# 방법2 -2 ; index 안쑴!

def solution(L, x):
  for num, target in enumerate(L):
    if x > target:
      pass
    else:
      #a = L.index(num)
      L.insert(numx)
      break
  if L[-1]<x:
    L.append(x)
  elif L[0]>x:
    L.insert(0,x)

  return L

L = [20, 37, 58, 72, 91]
solution(L,65)

L = [20, 37, 58, 72, 91]
solution(L,100)

def solution(L, x):
  if x in L :
    return [i for i , y in enumerate(L) if y == x]
  else:
    return [-1]

L = [64, 72, 83, 72, 54]
solution(L,1000)

L = [64, 72, 83, 72, 54]
solution(L,83)
# Out:
#   File "<ipython-input-6-04a4f19f5dc7>", line 124
#     if x > target:
#                   ^
# SyntaxError: unexpected EOF while parsing
