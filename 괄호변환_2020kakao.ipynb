# %% [markdown]
# <a href="https://colab.research.google.com/github/Nammyeung/Python/blob/master/%EA%B4%84%ED%98%B8%EB%B3%80%ED%99%98_2020kakao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def solution(p):
  print("시작 => p : %s" % p)
  if p=='': return p #비어있으면 그대로 리턴
  r = True; c = 0
  for i in range(len(p)):
    if p[i]=='(': 
      c -= 1 
      print("( 가 입력 => c : %d" % (c))
    else: 
      c += 1
      print(") 가 입력 => c : %d" % (c))
    if c>0: r=False
    if c==0:
      if r:
        print("p[:i+1] : %s " % p[:i+1])
        #print("solution[i+1:] : %s " % solution[i+1:])
        print("p[i+1:]부분 solution함수 적용 : %s" % p[i+1:])
        return p[:i+1]+solution(p[i+1:])
      else:
        print("****************************람다식 부분 실행*********************************")
        print("p[i+1:]부분 solution함수 적용 : %s" % p[i+1:])
        return '('+solution(p[i+1:])+')'+''.join(list(map(lambda x:'(' if x==')' else ')',p[1:i]) ))
        #lambda arguments : expression

p = [
    "(()())()",
    ")(",
    "()))((()"
]

idx = 1
for x in p:
  print("%s번째 답 : %s" % (idx, solution(x)))
  idx += 1
# Out:
# 시작 => p : (()())()
# ( 가 입력 => c : -1
# ( 가 입력 => c : -2
# ) 가 입력 => c : -1
# ( 가 입력 => c : -2
# ) 가 입력 => c : -1
# ) 가 입력 => c : 0
# p[:i+1] : (()())
# p[i+1:]부분 solution함수 적용 : ()
# 시작 => p : ()
# ( 가 입력 => c : -1
# ) 가 입력 => c : 0
# p[:i+1] : ()
# p[i+1:]부분 solution함수 적용 :
# 시작 => p :
# 1번째 답 : (()())()
# 시작 => p : )(
# ) 가 입력 => c : 1
# ( 가 입력 => c : 0
# ****************************람다식 부분 실행*********************************
# p[i+1:]부분 solution함수 적용 :
# 시작 => p :
# 2번째 답 : ()
# 시작 => p : ()))((()
# ( 가 입력 => c : -1
# ) 가 입력 => c : 0
# p[:i+1] : ()
# p[i+1:]부분 solution함수 적용 : ))((()
# 시작 => p : ))((()
# ) 가 입력 => c : 1
# ) 가 입력 => c : 2
# ( 가 입력 => c : 1
# ( 가 입력 => c : 0
# ****************************람다식 부분 실행*********************************
# p[i+1:]부분 solution함수 적용 : ()
# 시작 => p : ()
# ( 가 입력 => c : -1
# ) 가 입력 => c : 0
# p[:i+1] : ()
# p[i+1:]부분 solution함수 적용 :
# 시작 => p :
# 3번째 답 : ()(())()

# %%
p = "(()())()"
    #")(",
    #"()))((()"
for i in range(len(p)):
  print("p[1:i] : %s" % (p[1:i]))
  y = map(lambda x:'(' if x==')' else ')',p[1:i])
  print(list(map(lambda x:'(' if x==')' else ')',p[1:i]) ))
  '''
  The map() function executes a specified function for each item in an iterable. 
  The item is sent to the function as a parameter.
  '''

  #괄호 자체를 파이썬에서는 True라고 인식
# Out:
# p[1:i] :
# y : <map object at 0x7fd8917460b8>
# []
# p[1:i] :
# y : <map object at 0x7fd891746080>
# []
# p[1:i] : (
# y : <map object at 0x7fd891746208>
# [')']
# p[1:i] : ()
# y : <map object at 0x7fd891746ac8>
# [')', '(']
# p[1:i] : ()(
# y : <map object at 0x7fd891746208>
# [')', '(', ')']
# p[1:i] : ()()
# y : <map object at 0x7fd891746ac8>
# [')', '(', ')', '(']
# p[1:i] : ()())
# y : <map object at 0x7fd8917460b8>
# [')', '(', ')', '(', '(']
# p[1:i] : ()())(
# y : <map object at 0x7fd891746ac8>
# [')', '(', ')', '(', '(', ')']

# %%
#if "균형잡힌 괄호 문자열", then return True
def isBalancedString(str):
  print("'('와 ')'의 갯수는 동일합니까? : %s" % (str.count('(') == str.count(')')))
  return str.count('(') == str.count(')')

# if "올바른 괄호 문자열", then return True
def isCorrectString(str):
  count = 0
  for s in str:
    if s == '(':
      count += 1
    else: # ')'
      count -= 1
    if count < 0:
      return False
  print("'('와 ')'이 올바로 열고 닫혀있습니까? : %s" % (count == 0)))
  return count == 0

###############################True, False checker##############################

def process(str):
  # 1. 입력이 빈 문자열인 경우, 빈 문자열을 반환합니다.
  if str == "":
    return ""
  # 2. 문자열 w를 두 "균형잡힌 괄호 문자열" u, v로 분리합니다. 단, u는 "균형잡힌 괄호 문자열"로 더이상 분리할 수 없어야 하며, v는 빈 문자열이 될 수 있습니다.
  u, v = splitUV(str)
  print("나눠진 문자열 u : %s, v : %s" % (u, v))
  # 3. 문자열 u가 "올바른 괄호 문자열" 이라면 문자열 v에 대해 1단계부터 다시 수행합니다.
  # 3-1. 수행한 결과 문자열을 u에 이어 붙인 후 반환합니다.
  if isCorrectString(u):
    u += process(v)
    return u
  else: # 4. 문자열 u가 "올바른 괄호 문자열"이 아니라면 아래 과정을 수행합니다.
  # 4-1. 빈 문자열에 첫 번째 문자로 '('를 붙입니다.
    newStr = "("
  # 4-2. 문자열 v에 대해 1단계부터 재귀적으로 수행한 결과 문자열을 이어 붙입니다.
    newStr += process(v)
  # 4-3. ')'를 다시 붙입니다.
    newStr += ")"
  # 4-4. u의 첫 번째와 마지막 문자를 제거하고, 나머지 문자열의 괄호 방향을 뒤집어서 뒤에 붙입니다.
    if len(u) > 0:
      newStr += reverseStr(u[1:-1])
  # 4-5. 생성된 문자열을 반환합니다.
    return newStr

def reverseStr(str):
  ans = ""
  for s in str:
    if s == "(":
      ans += ")"
    else:
      ans += "("
  return ans

# 2. 문자열 w를 두 "균형잡힌 괄호 문자열" u, v로 분리합니다. 단, u는 "균형잡힌 괄호 문자열"로 더 이상 분리할 수 없어야 하며, v는 빈 문자열이 될 수 있습니다.

def splitUV(str):
  u, v = str, ""
  for i in range(2, len(str), 2):
    if isBalancedString(str[:i]):
      u = str[:i]
      v = str[i:]
      break
  return u, v

def solution(p):
  p = p.strip()
  print("시작 : %s" % p)

  if isCorrectString(p): # 이미 올바른 괄호 문자열이라면 그대로 return
    return p
  return process(p) # process(p) : 문자를 바꿔서 리턴

p = [
    "(()())()",
    ")(",
    "()))((()"
]

idx = 1
for x in p:
  print("%s번째 답 : %s" % (idx, solution(x)))
  idx += 1
# Out:
# 시작 : (()())()
# 1번째 답 : (()())()
# 시작 : )(
# 나눠진 문자열 u : )(, v :
# 2번째 답 : ()
# 시작 : ()))((()
# '('와 ')'의 갯수는 동일합니다 : True
# 나눠진 문자열 u : (), v : ))((()
# '('와 ')'의 갯수는 동일합니다 : False
# '('와 ')'의 갯수는 동일합니다 : True
# 나눠진 문자열 u : ))((, v : ()
# 나눠진 문자열 u : (), v :
# 3번째 답 : ()(())()
